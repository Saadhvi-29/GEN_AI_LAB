# %% [markdown]
# <a href="https://colab.research.google.com/github/Saadhvi-29/GEN_AI_LAB/blob/main/GenAI_LangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-community transformers torch

# %%
from langchain_community.llms import HuggingFacePipeline
from transformers import pipeline

# %%
hf_pipeline = pipeline(
    task="text2text-generation",
    model="google/flan-t5-small",
    max_new_tokens=100
)

llm = HuggingFacePipeline(pipeline=hf_pipeline)
# Out:
# Device set to use cpu

# %%
prompt = "Explain Natural Language Processing in 2 to 3 sentences."

response = llm.invoke(prompt)
print(response)
# Out:
# Natural language processing is the process of converting a language into a language.
